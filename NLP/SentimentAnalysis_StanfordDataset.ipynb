# %%
import json
import tensorflow as tf
import csv
import random
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers


embedding_dim = 100
max_length = 16
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size=160000
test_portion=.1

corpus = []

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv \
    -O /tmp/training_cleaned.csv

num_sentences = 0

with open("/tmp/training_cleaned.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        list_item=[]
        list_item.append(row[5])
        this_label=row[0]
        if this_label=='0':
            list_item.append(0)
        else:
            list_item.append(1)
        num_sentences = num_sentences + 1
        corpus.append(list_item)
# Out:
# --2021-10-09 15:55:30--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.13.128, 172.217.193.128, 172.217.204.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.13.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238942690 (228M) [application/octet-stream]
# Saving to: ‘/tmp/training_cleaned.csv’
#
# /tmp/training_clean 100%[===================>] 227.87M   245MB/s    in 0.9s
#
# 2021-10-09 15:55:31 (245 MB/s) - ‘/tmp/training_cleaned.csv’ saved [238942690/238942690]

# %%
print(num_sentences)
print(len(corpus))
print(corpus[1])
# Out:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]

# %%
sentences=[]
labels=[]
random.shuffle(corpus)
for x in range(training_size):
    sentences.append(corpus[x][0])
    labels.append(corpus[x][1])


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size=len(word_index)

sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

split = int(test_portion * training_size)

test_sequences = padded[0:split]
training_sequences = padded[split:training_size]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
test_sequences = np.array(test_sequences)
training_sequences = np.array(training_sequences)
test_labels = np.array(test_labels)
training_labels = np.array(training_labels)

# %%
print(vocab_size)
print(word_index['i'])
# Out:
# 139092
# 1

# %%
# Note this is the 100 dimension version of GloVe from Stanford

# glove.6B.100d.txt
# !gdown --id 1W5vZy2etitAblLdFn8_DxnsQKzfFJ98g

embeddings_index = {};
with open('./glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;

embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1W5vZy2etitAblLdFn8_DxnsQKzfFJ98g
# To: /content/glove.6B.100d.txt
# 100% 347M/347M [00:03<00:00, 103MB/s]

# %%
print(len(embeddings_matrix))
# Out:
# 139093

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=max_length, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50
history = model.fit(training_sequences, training_labels, epochs=num_epochs, validation_data=(test_sequences, test_labels), verbose=2)

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 16, 100)           13909300
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 100)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 12, 64)            32064
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3, 64)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 13,974,453
# Trainable params: 65,153
# Non-trainable params: 13,909,300
# _________________________________________________________________
# Epoch 1/50
# 4500/4500 - 27s - loss: 0.5656 - accuracy: 0.7020 - val_loss: 0.5483 - val_accuracy: 0.7153
# Epoch 2/50
# 4500/4500 - 24s - loss: 0.5258 - accuracy: 0.7325 - val_loss: 0.5174 - val_accuracy: 0.7413
# Epoch 3/50
# 4500/4500 - 24s - loss: 0.5099 - accuracy: 0.7440 - val_loss: 0.5136 - val_accuracy: 0.7465
# Epoch 4/50
# 4500/4500 - 23s - loss: 0.4989 - accuracy: 0.7535 - val_loss: 0.5087 - val_accuracy: 0.7487
# Epoch 5/50
# 4500/4500 - 25s - loss: 0.4891 - accuracy: 0.7599 - val_loss: 0.5033 - val_accuracy: 0.7506
# Epoch 6/50
# 4500/4500 - 23s - loss: 0.4823 - accuracy: 0.7632 - val_loss: 0.5076 - val_accuracy: 0.7453
# Epoch 7/50
# 4500/4500 - 23s - loss: 0.4768 - accuracy: 0.7670 - val_loss: 0.5065 - val_accuracy: 0.7500
# Epoch 8/50
# 4500/4500 - 23s - loss: 0.4721 - accuracy: 0.7696 - val_loss: 0.5105 - val_accuracy: 0.7514
# Epoch 9/50
# 4500/4500 - 23s - loss: 0.4663 - accuracy: 0.7733 - val_loss: 0.5043 - val_accuracy: 0.7542
# Epoch 10/50
# 4500/4500 - 23s - loss: 0.4626 - accuracy: 0.7751 - val_loss: 0.5159 - val_accuracy: 0.7464
# Epoch 11/50
# 4500/4500 - 23s - loss: 0.4595 - accuracy: 0.7772 - val_loss: 0.5087 - val_accuracy: 0.7498
# Epoch 12/50
# 4500/4500 - 23s - loss: 0.4566 - accuracy: 0.7791 - val_loss: 0.5077 - val_accuracy: 0.7511
# Epoch 13/50
# 4500/4500 - 23s - loss: 0.4535 - accuracy: 0.7812 - val_loss: 0.5096 - val_accuracy: 0.7502
# Epoch 14/50
# 4500/4500 - 23s - loss: 0.4521 - accuracy: 0.7828 - val_loss: 0.5104 - val_accuracy: 0.7508
# Epoch 15/50
# 4500/4500 - 23s - loss: 0.4497 - accuracy: 0.7828 - val_loss: 0.5101 - val_accuracy: 0.7530
# Epoch 16/50
# 4500/4500 - 23s - loss: 0.4473 - accuracy: 0.7844 - val_loss: 0.5131 - val_accuracy: 0.7491
# Epoch 17/50
# 4500/4500 - 23s - loss: 0.4455 - accuracy: 0.7858 - val_loss: 0.5202 - val_accuracy: 0.7466
# Epoch 18/50
# 4500/4500 - 23s - loss: 0.4442 - accuracy: 0.7868 - val_loss: 0.5105 - val_accuracy: 0.7504
# Epoch 19/50
# 4500/4500 - 23s - loss: 0.4428 - accuracy: 0.7871 - val_loss: 0.5121 - val_accuracy: 0.7501
# Epoch 20/50
# 4500/4500 - 23s - loss: 0.4418 - accuracy: 0.7887 - val_loss: 0.5143 - val_accuracy: 0.7489
# Epoch 21/50
# 4500/4500 - 23s - loss: 0.4403 - accuracy: 0.7891 - val_loss: 0.5187 - val_accuracy: 0.7515
# Epoch 22/50
# 4500/4500 - 23s - loss: 0.4380 - accuracy: 0.7911 - val_loss: 0.5195 - val_accuracy: 0.7477
# Epoch 23/50
# 4500/4500 - 23s - loss: 0.4375 - accuracy: 0.7908 - val_loss: 0.5231 - val_accuracy: 0.7493
# Epoch 24/50
# 4500/4500 - 23s - loss: 0.4359 - accuracy: 0.7914 - val_loss: 0.5191 - val_accuracy: 0.7483
# Epoch 25/50
# 4500/4500 - 22s - loss: 0.4362 - accuracy: 0.7913 - val_loss: 0.5197 - val_accuracy: 0.7481
# Epoch 26/50
# 4500/4500 - 23s - loss: 0.4350 - accuracy: 0.7929 - val_loss: 0.5197 - val_accuracy: 0.7456
# Epoch 27/50
# 4500/4500 - 23s - loss: 0.4344 - accuracy: 0.7938 - val_loss: 0.5175 - val_accuracy: 0.7479
# Epoch 28/50
# 4500/4500 - 23s - loss: 0.4335 - accuracy: 0.7939 - val_loss: 0.5207 - val_accuracy: 0.7501
# Epoch 29/50
# 4500/4500 - 23s - loss: 0.4328 - accuracy: 0.7937 - val_loss: 0.5197 - val_accuracy: 0.7475
# Epoch 30/50
# 4500/4500 - 23s - loss: 0.4309 - accuracy: 0.7945 - val_loss: 0.5211 - val_accuracy: 0.7487
# Epoch 31/50
# 4500/4500 - 23s - loss: 0.4317 - accuracy: 0.7944 - val_loss: 0.5247 - val_accuracy: 0.7467
# Epoch 32/50
# 4500/4500 - 23s - loss: 0.4309 - accuracy: 0.7951 - val_loss: 0.5235 - val_accuracy: 0.7449
# Epoch 33/50
# 4500/4500 - 23s - loss: 0.4307 - accuracy: 0.7952 - val_loss: 0.5190 - val_accuracy: 0.7484
# Epoch 34/50
# 4500/4500 - 23s - loss: 0.4304 - accuracy: 0.7943 - val_loss: 0.5197 - val_accuracy: 0.7483
# Epoch 35/50
# 4500/4500 - 23s - loss: 0.4304 - accuracy: 0.7950 - val_loss: 0.5237 - val_accuracy: 0.7502
# Epoch 36/50
# 4500/4500 - 23s - loss: 0.4277 - accuracy: 0.7962 - val_loss: 0.5248 - val_accuracy: 0.7487
# Epoch 37/50
# 4500/4500 - 23s - loss: 0.4287 - accuracy: 0.7960 - val_loss: 0.5295 - val_accuracy: 0.7481
# Epoch 38/50
# 4500/4500 - 23s - loss: 0.4286 - accuracy: 0.7963 - val_loss: 0.5283 - val_accuracy: 0.7482
# Epoch 39/50
# 4500/4500 - 23s - loss: 0.4279 - accuracy: 0.7972 - val_loss: 0.5246 - val_accuracy: 0.7484
# Epoch 40/50
# 4500/4500 - 23s - loss: 0.4281 - accuracy: 0.7968 - val_loss: 0.5262 - val_accuracy: 0.7482
# Epoch 41/50
# 4500/4500 - 23s - loss: 0.4294 - accuracy: 0.7955 - val_loss: 0.5211 - val_accuracy: 0.7477
# Epoch 42/50
# 4500/4500 - 23s - loss: 0.4284 - accuracy: 0.7962 - val_loss: 0.5236 - val_accuracy: 0.7502
# Epoch 43/50
# 4500/4500 - 23s - loss: 0.4276 - accuracy: 0.7959 - val_loss: 0.5284 - val_accuracy: 0.7478
# Epoch 44/50
# 4500/4500 - 23s - loss: 0.4262 - accuracy: 0.7983 - val_loss: 0.5275 - val_accuracy: 0.7471
# Epoch 45/50
# 4500/4500 - 24s - loss: 0.4260 - accuracy: 0.7989 - val_loss: 0.5263 - val_accuracy: 0.7459
# Epoch 46/50
# 4500/4500 - 23s - loss: 0.4267 - accuracy: 0.7976 - val_loss: 0.5273 - val_accuracy: 0.7437
# Epoch 47/50
# 4500/4500 - 23s - loss: 0.4249 - accuracy: 0.7990 - val_loss: 0.5301 - val_accuracy: 0.7455
# Epoch 48/50
# 4500/4500 - 24s - loss: 0.4258 - accuracy: 0.7980 - val_loss: 0.5287 - val_accuracy: 0.7466
# Epoch 49/50
# 4500/4500 - 24s - loss: 0.4265 - accuracy: 0.7970 - val_loss: 0.5264 - val_accuracy: 0.7489
# Epoch 50/50
# 4500/4500 - 23s - loss: 0.4248 - accuracy: 0.7988 - val_loss: 0.5257 - val_accuracy: 0.7456
# Training Complete

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])

plt.figure()
